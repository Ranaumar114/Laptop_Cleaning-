# %%
import pandas as pd

# %%
laptops = pd.read_csv('laptops.csv' , encoding = 'latin-1')

# %%
laptops
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
laptops.shape
# Out:
# (1303, 13)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
frq_man = pd.Series()

for i in laptops['Manufacturer']:
    if i not in frq_man:
        frq_man[i] = 1
    else:
        frq_man[i] += 1
frq_man
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_9344\2031575834.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   frq_man = pd.Series()
# Apple         21
# HP           274
# Acer         103
# Asus         158
# Dell         297
# Lenovo       297
# Chuwi          3
# MSI           54
# Microsoft      6
# Toshiba       48
# Huawei         2
# Xiaomi         4
# Vero           4
# Razer          7
# Mediacom       7
# Samsung        9
# Google         3
# Fujitsu        3
# LG             3
# dtype: int64

# %%
import csv

# %%
lap = list(csv.reader(open('laptops.csv' , encoding = 'latin-1')))

# %%
lap
# Out:
# [['Manufacturer',
#   'Model Name',
#   'Category',
#   'Screen Size',
#   'Screen',
#   'CPU',
#   'RAM',
#   ' Storage',
#   'GPU',
#   'Operating System',
#   'Operating System Version',
#   'Weight',
#   'Price (Euros)'],
#  ['Apple',
#   'MacBook Pro',
#   'Ultrabook',
#   '13.3"',
#   'IPS Panel Retina Display 2560x1600',
#   'Intel Core i5 2.3GHz',
#   '8GB',
#   '128GB SSD',
#   'Intel Iris Plus Graphics 640',
#   'macOS',
#   '',
#   '1.37kg',
#   '1339,69'],
#  ['Apple',
#   'Macbook Air',
#   'Ultrabook',
#   '13.3"',
#   '1440x900',
#   'Intel Core i5 1.8GHz',
#   '8GB',
#   '128GB Flash Storage',
#   'Intel HD Graphics 6000',
#   'macOS',
#   '',
#   '1.34kg',
#   '898,94'],
#  ['HP',
#   '250 G6',
#   'Notebook',
#   '15.6"',
#   'Full HD 1920x1080',
#   'Intel Core i5 7200U 2.5GHz',
#   '8GB',
#   '256GB SSD',
#   'Intel HD Graphics 620',
#   'No OS',
#   '',
#   '1.86kg',
#   '575,00'],
#  ['Apple',
#   'MacBook Pro',
#   'Ultrabook',
#   '15.4"',
# ...

# %%
frq_lap = {}

for i in lap[1:]:
    man = i[0]
    if man not in frq_lap:
        frq_lap[man] = 1
    else:
        frq_lap[man] += 1
frq_lap
# Out:
# {'Apple': 21,
#  'HP': 274,
#  'Acer': 103,
#  'Asus': 158,
#  'Dell': 297,
#  'Lenovo': 297,
#  'Chuwi': 3,
#  'MSI': 54,
#  'Microsoft': 6,
#  'Toshiba': 48,
#  'Huawei': 2,
#  'Xiaomi': 4,
#  'Vero': 4,
#  'Razer': 7,
#  'Mediacom': 7,
#  'Samsung': 9,
#  'Google': 3,
#  'Fujitsu': 3,
#  'LG': 3}

# %%
for google, i in laptops.iterrows():
    if i['Manufacturer'] == 'Google':
        print(i.values)
# Out:
# ['Google' 'Pixelbook (Core' 'Ultrabook' '12.3"' 'Touchscreen 2400x1600'
#  'Intel Core i7 7Y75 1.3GHz' '16GB' '512GB SSD' 'Intel HD Graphics 615'
#  'Chrome OS' nan '1.1kg' '2199,00']
# ['Google' 'Pixelbook (Core' 'Ultrabook' '12.3"' 'Touchscreen 2400x1600'
#  'Intel Core i5 7Y57 1.2GHz' '8GB' '128GB SSD' 'Intel HD Graphics 615'
#  'Chrome OS' nan '1.1kg' '1275,00']
# ['Google' 'Pixelbook (Core' 'Ultrabook' '12.3"' 'Touchscreen 2400x1600'
#  'Intel Core i5 7Y57 1.2GHz' '8GB' '256GB SSD' 'Intel HD Graphics 615'
#  'Chrome OS' nan '1.1kg' '1559,00']

# %%
laptops['Manufacturer'] == 'Google'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Manufacturer, Length: 1303, dtype: bool

# %%
laptops.loc[laptops['Manufacturer'] == 'Google']
# Out:
#     Manufacturer       Model Name   Category Screen Size  \
# 437       Google  Pixelbook (Core  Ultrabook       12.3"
# 472       Google  Pixelbook (Core  Ultrabook       12.3"
# 762       Google  Pixelbook (Core  Ultrabook       12.3"
#
#                     Screen                        CPU   RAM    Storage  \
# 437  Touchscreen 2400x1600  Intel Core i7 7Y75 1.3GHz  16GB  512GB SSD
# 472  Touchscreen 2400x1600  Intel Core i5 7Y57 1.2GHz   8GB  128GB SSD
# 762  Touchscreen 2400x1600  Intel Core i5 7Y57 1.2GHz   8GB  256GB SSD
#
#                        GPU Operating System Operating System Version Weight  \
# 437  Intel HD Graphics 615        Chrome OS                      NaN  1.1kg
# 472  Intel HD Graphics 615        Chrome OS                      NaN  1.1kg
# 762  Intel HD Graphics 615        Chrome OS                      NaN  1.1kg
#
#     Price (Euros)
# 437       2199,00
# 472       1275,00
# 762       1559,00

# %%
[laptops['Manufacturer'] == 'Google' , 'GPU']
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1298    False
#  1299    False
#  1300    False
#  1301    False
#  1302    False
#  Name: Manufacturer, Length: 1303, dtype: bool,
#  'GPU']

# %%
laptops[(laptops['Manufacturer'] == 'Google') & (laptops['RAM'] == '8GB')]
# Out:
#     Manufacturer       Model Name   Category Screen Size  \
# 472       Google  Pixelbook (Core  Ultrabook       12.3"
# 762       Google  Pixelbook (Core  Ultrabook       12.3"
#
#                     Screen                        CPU  RAM    Storage  \
# 472  Touchscreen 2400x1600  Intel Core i5 7Y57 1.2GHz  8GB  128GB SSD
# 762  Touchscreen 2400x1600  Intel Core i5 7Y57 1.2GHz  8GB  256GB SSD
#
#                        GPU Operating System Operating System Version Weight  \
# 472  Intel HD Graphics 615        Chrome OS                      NaN  1.1kg
# 762  Intel HD Graphics 615        Chrome OS                      NaN  1.1kg
#
#     Price (Euros)
# 472       1275,00
# 762       1559,00

# %%
laptops.loc[laptops['Manufacturer'] == 'Google' , ['RAM' , 'Manufacturer']]
# Out:
#       RAM Manufacturer
# 437  16GB       Google
# 472   8GB       Google
# 762   8GB       Google

# %%
laptops[(laptops['Manufacturer'] == 'Dell') & (laptops['RAM'] == '8GB')]
# Out:
#      Manufacturer     Model Name            Category Screen Size  \
# 16           Dell  Inspiron 3567            Notebook       15.6"
# 19           Dell         XPS 13           Ultrabook       13.3"
# 23           Dell  Inspiron 5379  2 in 1 Convertible       13.3"
# 27           Dell  Inspiron 5570            Notebook       15.6"
# 28           Dell  Latitude 5590           Ultrabook       15.6"
# ...           ...            ...                 ...         ...
# 1232         Dell  Inspiron 3567            Notebook       15.6"
# 1249         Dell         XPS 13  2 in 1 Convertible       13.3"
# 1267         Dell  Inspiron 3567            Notebook       15.6"
# 1281         Dell  Inspiron 3567            Notebook       15.6"
# 1295         Dell  Inspiron 3567            Notebook       15.6"
#
#                                          Screen                         CPU  \
# 16                            Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# ...

# %%
laptops.loc[laptops['Manufacturer'] == 'Razer' , ['Manufacturer' ,'Weight' ,'RAM']]
# Out:
#      Manufacturer  Weight   RAM
# 196         Razer  3.49kg  32GB
# 647         Razer  1.95kg  16GB
# 778         Razer  1.95kg  16GB
# 816         Razer  1.29kg  16GB
# 830         Razer  3.49kg  32GB
# 1117        Razer  1.25kg   8GB
# 1231        Razer  1.95kg  16GB

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
laptops.columns = laptops.columns.str.strip().str.lower().str.replace('(','').str.replace(')','')\
.str.replace(' ','_').str.replace('operating_system','os')
# Out:
# C:\Users\umar\AppData\Local\Temp\ipykernel_9344\1173086237.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns = laptops.columns.str.strip().str.lower().str.replace('(','').str.replace(')','')\
# C:\Users\umar\AppData\Local\Temp\ipykernel_9344\1173086237.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptops.columns = laptops.columns.str.strip().str.lower().str.replace('(','').str.replace(')','')\

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   object
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
laptops['screen_size'] = laptops['screen_size'].str.strip('"').astype(float)

# %%
laptops['screen_size']
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: screen_size, Length: 1303, dtype: float64

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  os_version    1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 132.5+ KB

# %%
laptops['screen_size'].mean()
# Out:
# 15.017191097467265

# %%
laptops.rename({'screen_size' : "screen_size_inch"}, axis= 1 , inplace= True)

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops['cpu_manufacture'] = laptops['cpu'].str.split(n=1, expand= True)[0]

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops['cpu_manufacture'].value_counts()
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: cpu_manufacture, dtype: int64

# %%
laptops['gpu_manufacture'] = laptops['gpu'].str.split(n=1 , expand= True)[0]

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops['gpu_manufacture'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: gpu_manufacture, dtype: int64

# %%
laptops['screen_size_inch'].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: screen_size_inch, dtype: int64

# %%
laptops['os'].value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: os, dtype: int64

# %%
laptops['os'] = laptops['os'].str.replace('Mac OS','macOS')

# %%
laptops['os'].value_counts()
# Out:
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          21
# Android         2
# Name: os, dtype: int64

# %%
laptops['weight'].value_counts()
# Out:
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: weight, Length: 179, dtype: int64

# %%
laptops['weight'] = laptops['weight'].str.replace('kg','').str.replace('kgs','').str.replace('s','').astype(float)

# %%
laptops['weight'].mean()
# Out:
# 2.038733691481197

# %%
laptops.rename({'weight' : 'weight_kg'} , axis=1 , inplace= True)

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   manufacturer      1303 non-null   object
#  1   model_name        1303 non-null   object
#  2   category          1303 non-null   object
#  3   screen_size_inch  1303 non-null   float64
#  4   screen            1303 non-null   object
#  5   cpu               1303 non-null   object
#  6   ram               1303 non-null   object
#  7   storage           1303 non-null   object
#  8   gpu               1303 non-null   object
#  9   os                1303 non-null   object
#  10  os_version        1133 non-null   object
#  11  weight_kg         1303 non-null   float64
#  12  price_euros       1303 non-null   object
#  13  cpu_manufacture   1303 non-null   object
#  14  gpu_manufacture   1303 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 152.8+ KB

# %%
laptops['price_euros'] = laptops['price_euros'].str.replace(',','').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9344\2064586949.py in <module>
# ----> 1 laptops['price_euros'] = laptops['price_euros'].str.replace(',','').astype(float)
#
# F:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# F:\Anaconda\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %%
laptops['price_euros'].mean()
# Out:
# 112368.69915579433

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops['os_version'].value_counts()
# Out:
# 10      1072
# 7         45
# X          8
# 10 S       8
# Name: os_version, dtype: int64

# %%
laptops.loc[laptops['os_version'].isnull() , 'os_version'] = 'Unknown_Version'

# %%
laptops['os_version'].value_counts()
# Out:
# 10                 1072
# Unknown_Version     170
# 7                    45
# X                     8
# 10 S                  8
# Name: os_version, dtype: int64

# %%
laptops['os_version'] = laptops['os_version'].str.replace(' ','')

# %%
laptops['os_version'].value_counts()
# Out:
# 10                 1072
# Unknown_Version     170
# 7                    45
# X                     8
# 10S                   8
# Name: os_version, dtype: int64

# %%
laptops.to_csv('laptops_cleaning.csv' , index= False)
